# %%
import numpy as np

# %% [markdown]
# ## 변수명 정하는 규칙
# - 아래 줄에서는 X를 대문자로 적었는데 대문자로 적는 이유는 다차원이기 때문에
# - 대문자이긴 하지만 1차원인데, 이유는 단순한 예제이기 때문에

# %% [markdown]
# ##### 아래 X는 독립변수

# %%
X = np.array([1, 2, 3], dtype="float32")
X
# Out:
# array([1., 2., 3.], dtype=float32)

# %% [markdown]
# ##### 아래 y는 종속변수

# %%
y = np.array([2, 2.5, 3.5], dtype="float32")
y
# Out:
# array([2. , 2.5, 3.5], dtype=float32)

# %% [markdown]
# #####  아래  w와 b는 초기화 가중치와 bias

# %%
w = 2
b = 1

# %% [markdown]
# ##### 아래 hypothesis는 예측값

# %%
hypothesis = X * w + b
hypothesis
# Out:
# array([3., 5., 7.], dtype=float32)

# %%
hypothesis-y
# Out:
# array([1. , 2.5, 3.5], dtype=float32)

# %% [markdown]
# 원래 안되야 하는데 numpy에서 알아서 바꿔주는 듯

# %%
w_grad = 1/3 * np.dot((hypothesis - y), X)
w_grad
# Out:
# 5.5

# %%
b_grad = np.sum(hypothesis - y)/3
b_grad
# Out:
# 2.3333333333333335

# %%
w = w-w_grad
w
# Out:
# -3.5

# %%
b = b-b_grad
b
# Out:
# -1.3333333333333335

# %% [markdown]
# ##### 어느순간 overshooting이 나버린다
# #### 이유는 grad 량이 너무 커져서 그렇기 때문

# %%
for i in range(100):
    hypothesis = X * w + b
    print(f'{i+1}번째 hypothesis = {hypothesis}')
    cost = np.sum((hypothesis - y)**2)
    print(f'{i+1}번째 cost = {cost}')
    w_grad = 1/len(X)*np.dot((hypothesis - y), X.T)
    print(f'{i+1}번째 w_grad = {w_grad}')
    b_grad = 1/len(X) * np.sum(hypothesis - y)/3
    w -= w_grad
    b -= b_grad
    print(f'{i+1}번째 w = {w}, b = {b}')
# Out:
# 1번째 hypothesis = [ -4.8333335  -8.333333  -11.833333 ]
# 1번째 cost = 399.1666564941406
# 1번째 w_grad = -24.833333333333332
# 1번째 w = 21.333333333333332, b = 2.333333333333333
# 2번째 hypothesis = [23.666668 45.       66.333336]
# 2번째 cost = 6223.72265625
# 2번째 w_grad = 98.38888549804688
# 2번째 w = -77.05555216471355, b = -11.777778625488281
# 3번째 hypothesis = [ -88.83333 -165.88889 -242.94443]
# 3번째 cost = 97340.359375
# 3번째 w_grad = -388.9814453125
# 3번째 w = 311.92589314778644, b = 44.40740542941623
# 4번째 hypothesis = [356.3333 668.2592 980.1851]
# 4번째 cost = 1522701.25
# 4번째 w_grad = 1538.6357421875
# 4번째 w = -1226.7098490397136, b = -177.45677100287543
# 5번째 hypothesis = [-1404.1666 -2630.8765 -3857.5862]
# 5번째 cost = 23819964.0
# 5번째 w_grad = -6085.392578125
# 5번째 w = 4858.682729085286, b = 700.3908852471245
# 6번째 hypothesis = [ 5559.073 10417.756 15276.438]
# 6번째 cost = 372621280.0
# 6번째 w_grad = 24068.799479166664
# 6번째 w = -19210.11675008138, b = -2771.3055123223194
# 7번째 hypothesis = [-21981.422 -41191.54  -60401.656]
# 7번째 cost = 5829002240.0
# 7번째 w_grad = -95195.65625
# 7번째 w = 75985.53949991862, b = 10960.096397399902
# 8번째 hypothesis = [ 86945.63 162931.17 238916.72]
# 8번째 cost = 91184472064.0
# 8번째 w_grad = 376513.5416666666
# 8번째 w = -300528.002166748, b = -43349.40707482232
# 9번째 hypothesis = [-343877.4 -644405.4 -944933.4]
# 9번째 cost = 1426420269056.0
# 9번째 w_grad = -1489168.5
# 9번째 w = 1188640.497833252, b = 171453.27348073322
# 10번째 hypothesis = [1360093.8 2548734.2 3737374.8]
# 10번째 cost = 22313827303424.0
# 10번째 w_grad = 5889890.0
# 10번째 w = -4701249.502166748, b = -678123.9487414889
# 11번째 hypothesis = [ -5379373.5 -10080623.  -14781872. ]
# 11번째 cost = 349060548526080.0
# 11번째 w_grad = -23295418.666666664
# 11번째 w = 18594169.164499916, b = 2682084.717925178
# 12번째 hypothesis = [21276254. 39870424. 58464596.]
# 12번째 cost = 5460437810282496.0
# 12번째 w_grad = 92136960.0
# 12번째 w = -73542790.83550009, b = -10608055.726519264
# 13번째 hypothesis = [-8.4150848e+07 -1.5769363e+08 -2.3123645e+08]
# 13번째 cost = 8.54189452380078e+16
# 13번째 w_grad = -364415829.3333333
# 13번째 w = 290873038.49783325, b = 41956491.82903629
# 14번째 hypothesis = [3.3282950e+08 6.2370253e+08 9.1457555e+08]
# 14번째 cost = 1.3362287846547784e+18
# 14번째 w_grad = 1441320448.0
# 14번째 w = -1150447409.5021667, b = -165944350.83763036
# 15번째 hypothesis = [-1.3163917e+09 -2.4668390e+09 -3.6172864e+09]
# 15번째 cost = 2.090294309899836e+19
# 15번째 w_grad = -5700643157.333333
# 15번째 w = 4550195747.831166, b = 656335329.1623696
# 16번째 hypothesis = [5.2065311e+09 9.7567273e+09 1.4306922e+10]
# 16번째 cost = 3.269897267353737e+20
# 16번째 w_grad = 22546918058.666664
# 16번째 w = -17996722310.8355, b = -2595906875.2820745
# 17번째 hypothesis = [-2.0592630e+10 -3.8589350e+10 -5.6586072e+10]
# 17번째 cost = 5.115177760718294e+21
# 17번째 w_grad = -89176511829.33333
# 17번째 w = 71179789518.49783, b = 10267209754.05126
# 18번째 hypothesis = [8.1446994e+10 1.5262679e+11 2.2380657e+11]
# 18번째 cost = 8.001793155928666e+22
# 18번째 w_grad = 352706756608.0
# 18번째 w = -281526967089.5022, b = -40608387045.94874
# 19번째 hypothesis = [-3.2213536e+11 -6.0366232e+11 -8.8518931e+11]
# 19번째 cost = 1.2517395596882044e+24
# 19번째 w_grad = -1395009344853.3333
# 19번째 w = 1113482377763.831, b = 160612386159.3846
# 20번째 hypothesis = [1.2740947e+12 2.3875771e+12 3.5010595e+12]
# 20번째 cost = 1.9581260339416855e+25
# 20번째 w_grad = 5517475840000.0
# 20번째 w = -4403993462236.169, b = -635246661605.9487
# 21번째 hypothesis = [-5.0392402e+12 -9.4432332e+12 -1.3847226e+13]
# 21번째 cost = 3.0631427276949143e+26
# 21번째 w_grad = -21822461793621.332
# 21번째 w = 17418468331385.164, b = 2512497866550.495
# 22번째 hypothesis = [1.9930966e+13 3.7349434e+13 5.4767905e+13]
# 22번째 cost = 4.791747196088061e+27
# 22번째 w_grad = 86311181833557.33
# 22번째 w = -68892713502172.164, b = -9937313954448.613
# 23번째 hypothesis = [-7.8830031e+13 -1.4772275e+14 -2.1661545e+14]
# 23번째 cost = 7.495843958114423e+28
# 23번째 w_grad = -341373955167573.3
# 23번째 w = 272481241665401.16, b = 39303598765878.484
# 24번째 hypothesis = [3.1178483e+14 5.8426608e+14 8.5674733e+14]
# 24번째 cost = 1.1725926119162037e+30
# 24번째 w_grad = 1350186320265216.0
# 24번째 w = -1077705078599814.9, b = -155451752923565.06
# 25번째 hypothesis = [-1.2331568e+15 -2.3108618e+15 -3.3885671e+15]
# 25번째 cost = 1.8343145100039812e+31
# 25번째 w_grad = -5340193758380032.0
# 25번째 w = 4262488679780217.0, b = 614835539576175.2
# 26번째 hypothesis = [4.8773241e+15 9.1398128e+15 1.3402302e+16]
# 26번째 cost = 2.869461643538991e+32
# 26번째 w_grad = 2.11212862254394e+16
# 26번째 w = -1.6858797545659184e+16, b = -2431768731242470.0
# 27번째 hypothesis = [-1.9290566e+16 -3.6149365e+16 -5.3008160e+16]
# 27번째 cost = 4.4887677970837005e+33
# 27번째 w_grad = -8.35379270876747e+16
# 27번째 w = 6.667912954201552e+16, b = 9618019715723290.0
# 28번째 hypothesis = [7.6297148e+16 1.4297628e+17 2.0965541e+17]
# 28번째 cost = 7.021886075971885e+34
# 28번째 w_grad = 3.304053057309901e+17
# 28번째 w = -2.6372617618897456e+17, b = -3.804073937808267e+16
# 29번째 hypothesis = [-3.017669e+17 -5.654931e+17 -8.292193e+17]
# 29번째 cost = 1.0984503817656289e+36
# 29번째 w_grad = -1.306803654472237e+18
# 29번째 w = 1.0430774782832625e+18, b = 1.504569685607033e+17
# 30번째 hypothesis = [1.1935344e+18 2.2366120e+18 3.2796893e+18]
# 30번째 cost = 1.7183318263442506e+37
# 30번째 w_grad = 5.168608815609107e+18
# 30번째 w = -4.125531337325845e+18, b = -5.95080329128264e+17
# 31번째 hypothesis = [-4.7206119e+18 -8.8461433e+18 -1.2971674e+19]
# 31번째 cost = 2.68802754194786e+38
# 31번째 w_grad = -2.0442640619115205e+19
# 31번째 w = 1.631710928178936e+19, b = 2.353633934706524e+18
# 32번째 hypothesis = [1.8670743e+19 3.4987852e+19 5.1304959e+19]
# 32번째 cost = inf
# 32번째 w_grad = 8.085377502106616e+19
# 32번째 w = -6.45366657392768e+19, b = -9.308982658136752e+18
# 33번째 hypothesis = [-7.3845646e+19 -1.3838232e+20 -2.0291897e+20]
# 33번째 cost = inf
# 33번째 w_grad = -3.197890690655338e+20
# 33번째 w = 2.55252403326257e+20, b = 3.681845629401184e+19
# 34번째 hypothesis = [2.9207086e+20 5.4732324e+20 8.0257565e+20]
# 34번째 cost = inf
# 34번째 w_grad = 1.264814750898758e+21
# 34번째 w = -1.0095623475725012e+21, b = -1.4562263044824495e+20
# 35번째 hypothesis = [-1.1551850e+21 -2.1647473e+21 -3.1743098e+21]
# 35번째 cost = inf
# 35번째 w_grad = -5.002536166288301e+21
# 35번째 w = 3.9929738187158e+21, b = 5.759598644477517e+20
# 36번째 hypothesis = [4.5689339e+21 8.5619075e+21 1.2554882e+22]
# 36번째 cost = inf
# 36번째 w_grad = 1.9785797849715743e+22
# 36번째 w = -1.5792824030999943e+22, b = -2.2780092498137847e+21
# 37번째 hypothesis = [-1.8070833e+22 -3.3863655e+22 -4.9656482e+22]
# 37번째 cost = inf
# 37번째 w_grad = -7.825586217628093e+22
# 37번째 w = 6.246303814528099e+22, b = 9.009876907422325e+21
# 38번째 hypothesis = [7.1472919e+22 1.3393595e+23 1.9639901e+23]
# 38번째 cost = inf
# 38번째 w_grad = 3.095139316259024e+23
# 38번째 w = -2.4705089348062143e+23, b = -3.563544310740733e+22
# 39번째 hypothesis = [-2.8268634e+23 -5.2973724e+23 -7.7678814e+23]
# 39번째 cost = inf
# 39번째 w_grad = -1.2241751280488956e+24
# 39번째 w = 9.77124234568274e+23, b = 1.4094364464397343e+23
# 40번째 hypothesis = [1.1180679e+24 2.0951921e+24 3.0723162e+24]
# 40번째 cost = inf
# 40번째 w_grad = 4.841800311682046e+24
# 40번째 w = -3.864676077113771e+24, b = -5.574536728535734e+23
# 41번째 hypothesis = [-4.4221299e+24 -8.2868061e+24 -1.2151483e+25]
# 41번째 cost = inf
# 41번째 w_grad = -1.9150063085007876e+25
# 41번째 w = 1.5285387007894106e+25, b = 2.2048150753376852e+24
# 42번째 hypothesis = [1.7490202e+25 3.2775589e+25 4.8060976e+25]
# 42번째 cost = inf
# 42번째 w_grad = 7.574143342510649e+25
# 42번째 w = -6.045604641721239e+25, b = -8.72038183241947e+24
# 43번째 hypothesis = [-6.9176425e+25 -1.2963247e+26 -1.9008851e+26]
# 43번째 cost = inf
# 43번째 w_grad = -2.9956897484235187e+26
# 43번째 w = 2.3911292842513946e+26, b = 3.449044387890558e+25
# 44번째 hypothesis = [2.7360338e+26 5.1271629e+26 7.5182930e+26]
# 44번째 cost = inf
# 44번째 w_grad = 1.1848412586388186e+27
# 44번째 w = -9.457283302136791e+26, b = -1.3641499980651618e+26
# 45번째 hypothesis = [-1.08214334e+27 -2.02787168e+27 -2.97360009e+27]
# 45번째 cost = inf
# 45번째 w_grad = -4.686228966890025e+27
# 45번째 w = 3.740500636676346e+27, b = 5.395422429566267e+26
# 46번째 hypothesis = [4.2800428e+27 8.0205434e+27 1.1761044e+28]
# 46번째 cost = inf
# 46번째 w_grad = 1.8534754817850793e+28
# 46번째 w = -1.4794254181174447e+28, b = -2.1339722835202435e+27
# 47번째 hypothesis = [-1.6928227e+28 -3.1722480e+28 -4.6516736e+28]
# 47번째 cost = inf
# 47번째 w_grad = -7.330780091606574e+28
# 47번째 w = 5.851354673489129e+28, b = 8.440188085631501e+27
# 48번째 hypothesis = [6.6953731e+28 1.2546728e+29 1.8398083e+29]
# 48번째 cost = inf
# 48번째 w_grad = 2.8994358026973013e+29
# 48번째 w = -2.314300335348388e+29, b = -3.3382239645254343e+28
# 49번째 hypothesis = [-2.6481227e+29 -4.9624229e+29 -7.2767232e+29]
# 49번째 cost = inf
# 49번째 w_grad = -1.1467712157069639e+30
# 49번째 w = 9.153411821721251e+29, b = 1.3203185645042974e+29
# 50번째 hypothesis = [1.04737306e+30 1.96271434e+30 2.87805555e+30]
# 50번째 cost = inf
# 50번째 w_grad = 4.5356559495356296e+30
# 50번째 w = -3.6203147673635046e+30, b = -5.22206290452969e+29
# 51번째 hypothesis = [-4.1425212e+30 -7.7628361e+30 -1.1383151e+31]
# 51번째 cost = inf
# 51번째 w_grad = -1.7939216387338533e+31
# 51번째 w = 1.4318901619975029e+31, b = 2.0654059361687611e+30
# 52번째 hypothesis = [1.6384308e+31 3.0703210e+31 4.5022109e+31]
# 52번째 cost = inf
# 52번째 w_grad = 7.095235281871917e+31
# 52번째 w = -5.663345119874414e+31, b = -8.168996837642439e+30
# 53번째 hypothesis = [-6.4802447e+31 -1.2143590e+32 -1.7806934e+32]
# 53번째 cost = inf
# 53번째 w_grad = -2.8062744114639853e+32
# 53번째 w = 2.239939899476544e+32, b = 3.2309635092828565e+31
# 54번째 hypothesis = [2.5630363e+32 4.8029760e+32 7.0429163e+32]
# 54번째 cost = inf
# 54번째 w_grad = 1.1099245566612091e+33
# 54번째 w = -8.859305667135547e+32, b = -1.2778957391672507e+32
# 55번째 hypothesis = [-1.0137202e+33 -1.8996507e+33 -2.7855811e+33]
# 55번째 cost = inf
# 55번째 w_grad = -4.3899214829585306e+33
# 55번째 w = 3.503990916244976e+33, b = 5.054273474425274e+32
# 56번째 hypothesis = [4.0094182e+33 7.5134091e+33 1.1017400e+34]
# 56번째 cost = inf
# 56번째 w_grad = 1.7362812200919772e+34
# 56번째 w = -1.3858821284674798e+34, b = -1.9990425436888493e+33
# 57번째 hypothesis = [-1.5857865e+34 -2.9716686e+34 -4.3575504e+34]
# 57번째 cost = inf
# 57번째 w_grad = -6.867258121779514e+34
# 57번째 w = 5.481375993312035e+34, b = 7.90651899617008e+33
# 58번째 hypothesis = [6.2720282e+34 1.1753404e+35 1.7234779e+35]
# 58번째 cost = inf
# 58번째 w_grad = 2.716105677379261e+35
# 58번째 w = -2.167968078048057e+35, b = -3.127149485604816e+34
# 59번째 hypothesis = [-2.4806831e+35 -4.6486514e+35 -6.8166192e+35]
# 59번째 cost = inf
# 59번째 w_grad = -1.0742614163341113e+36
# 59번째 w = 8.574646085293055e+35, b = 1.2368354400213344e+35
# 60번째 hypothesis = [9.8114818e+35 1.8386128e+36 2.6960773e+36]
# 60번째 cost = inf
# 60번째 w_grad = 4.248868604274771e+36
# 60번째 w = -3.391403995745466e+36, b = -4.891873508401418e+35
# 61번째 hypothesis = [-3.8805913e+36 -7.2719956e+36 -1.0663400e+37]
# 61번째 cost = inf
# 61번째 w_grad = -1.6804926249475178e+37
# 61번째 w = 1.3413522253729713e+37, b = 1.9348113099149446e+36
# 62번째 hypothesis = [1.5348333e+37 2.8761856e+37 4.2175374e+37]
# 62번째 cost = inf
# 62번째 w_grad = 6.646605798265143e+37
# 62번째 w = -5.305253572892172e+37, b = -7.652474124831963e+36
# 63번째 hypothesis = [-6.0705009e+37 -1.1375755e+38 -1.6681008e+38]
# 63번째 cost = inf
# 63번째 w_grad = -inf
# 63번째 w = inf, b = inf
# 64번째 hypothesis = [inf inf inf]
# 64번째 cost = inf
# 64번째 w_grad = inf
# 64번째 w = nan, b = nan
# 65번째 hypothesis = [nan nan nan]
# 65번째 cost = nan
# 65번째 w_grad = nan
# 65번째 w = nan, b = nan
# 66번째 hypothesis = [nan nan nan]
# 66번째 cost = nan
# 66번째 w_grad = nan
# 66번째 w = nan, b = nan
# 67번째 hypothesis = [nan nan nan]
# 67번째 cost = nan
# 67번째 w_grad = nan
# 67번째 w = nan, b = nan
# 68번째 hypothesis = [nan nan nan]
# 68번째 cost = nan
# 68번째 w_grad = nan
# 68번째 w = nan, b = nan
# 69번째 hypothesis = [nan nan nan]
# 69번째 cost = nan
# 69번째 w_grad = nan
# 69번째 w = nan, b = nan
# 70번째 hypothesis = [nan nan nan]
# 70번째 cost = nan
# 70번째 w_grad = nan
# 70번째 w = nan, b = nan
# 71번째 hypothesis = [nan nan nan]
# 71번째 cost = nan
# 71번째 w_grad = nan
# 71번째 w = nan, b = nan
# 72번째 hypothesis = [nan nan nan]
# 72번째 cost = nan
# 72번째 w_grad = nan
# 72번째 w = nan, b = nan
# 73번째 hypothesis = [nan nan nan]
# 73번째 cost = nan
# 73번째 w_grad = nan
# 73번째 w = nan, b = nan
# 74번째 hypothesis = [nan nan nan]
# 74번째 cost = nan
# 74번째 w_grad = nan
# 74번째 w = nan, b = nan
# 75번째 hypothesis = [nan nan nan]
# 75번째 cost = nan
# 75번째 w_grad = nan
# 75번째 w = nan, b = nan
# 76번째 hypothesis = [nan nan nan]
# 76번째 cost = nan
# 76번째 w_grad = nan
# 76번째 w = nan, b = nan
# 77번째 hypothesis = [nan nan nan]
# 77번째 cost = nan
# 77번째 w_grad = nan
# 77번째 w = nan, b = nan
# 78번째 hypothesis = [nan nan nan]
# 78번째 cost = nan
# 78번째 w_grad = nan
# 78번째 w = nan, b = nan
# 79번째 hypothesis = [nan nan nan]
# 79번째 cost = nan
# 79번째 w_grad = nan
# 79번째 w = nan, b = nan
# 80번째 hypothesis = [nan nan nan]
# 80번째 cost = nan
# 80번째 w_grad = nan
# 80번째 w = nan, b = nan
# 81번째 hypothesis = [nan nan nan]
# 81번째 cost = nan
# 81번째 w_grad = nan
# 81번째 w = nan, b = nan
# 82번째 hypothesis = [nan nan nan]
# 82번째 cost = nan
# 82번째 w_grad = nan
# 82번째 w = nan, b = nan
# 83번째 hypothesis = [nan nan nan]
# 83번째 cost = nan
# 83번째 w_grad = nan
# 83번째 w = nan, b = nan
# 84번째 hypothesis = [nan nan nan]
# 84번째 cost = nan
# 84번째 w_grad = nan
# 84번째 w = nan, b = nan
# 85번째 hypothesis = [nan nan nan]
# 85번째 cost = nan
# 85번째 w_grad = nan
# 85번째 w = nan, b = nan
# 86번째 hypothesis = [nan nan nan]
# 86번째 cost = nan
# 86번째 w_grad = nan
# 86번째 w = nan, b = nan
# 87번째 hypothesis = [nan nan nan]
# 87번째 cost = nan
# 87번째 w_grad = nan
# 87번째 w = nan, b = nan
# 88번째 hypothesis = [nan nan nan]
# 88번째 cost = nan
# 88번째 w_grad = nan
# 88번째 w = nan, b = nan
# 89번째 hypothesis = [nan nan nan]
# 89번째 cost = nan
# 89번째 w_grad = nan
# 89번째 w = nan, b = nan
# 90번째 hypothesis = [nan nan nan]
# 90번째 cost = nan
# 90번째 w_grad = nan
# 90번째 w = nan, b = nan
# 91번째 hypothesis = [nan nan nan]
# 91번째 cost = nan
# 91번째 w_grad = nan
# 91번째 w = nan, b = nan
# 92번째 hypothesis = [nan nan nan]
# 92번째 cost = nan
# 92번째 w_grad = nan
# 92번째 w = nan, b = nan
# 93번째 hypothesis = [nan nan nan]
# 93번째 cost = nan
# 93번째 w_grad = nan
# 93번째 w = nan, b = nan
# 94번째 hypothesis = [nan nan nan]
# 94번째 cost = nan
# 94번째 w_grad = nan
# 94번째 w = nan, b = nan
# 95번째 hypothesis = [nan nan nan]
# 95번째 cost = nan
# 95번째 w_grad = nan
# 95번째 w = nan, b = nan
# 96번째 hypothesis = [nan nan nan]
# 96번째 cost = nan
# 96번째 w_grad = nan
# 96번째 w = nan, b = nan
# 97번째 hypothesis = [nan nan nan]
# 97번째 cost = nan
# 97번째 w_grad = nan
# 97번째 w = nan, b = nan
# 98번째 hypothesis = [nan nan nan]
# 98번째 cost = nan
# 98번째 w_grad = nan
# 98번째 w = nan, b = nan
# 99번째 hypothesis = [nan nan nan]
# 99번째 cost = nan
# 99번째 w_grad = nan
# 99번째 w = nan, b = nan
# 100번째 hypothesis = [nan nan nan]
# 100번째 cost = nan
# 100번째 w_grad = nan
# 100번째 w = nan, b = nan
# c:\library\python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in square
#   after removing the cwd from sys.path.
# c:\library\python\lib\site-packages\numpy\core\fromnumeric.py:90: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# c:\library\python\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':
# c:\library\python\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Overshooting을 막기 위해 learning rate를 설정

# %%
learning_rate = 0.1
hypothesis_list = []
cost_list = []

for i in range(100):
    hypothesis = X * w + b
    print(f'{i+1}번째 hypothesis = {hypothesis}')
    cost = np.sum((hypothesis - y)**2)
    print(f'{i+1}번째 cost = {cost}')
    w_grad = 1/len(X)*np.dot((hypothesis - y), X.T)
    print(f'{i+1}번째 w_grad = {w_grad}')
    b_grad = 1/len(X) * np.sum(hypothesis - y)/3
    w -= learning_rate * w_grad
    b -= learning_rate * b_grad
    hypothesis_list.append(hypothesis)
    cost_list.append(cost)
    print(f'{i+1}번째 w = {w}, b = {b}')
# Out:
# 1번째 hypothesis = [1.7984762 2.6386352 3.4787943]
# 1번째 cost = 0.06028122082352638
# 1번째 w_grad = 0.004043181737263997
# 1번째 w = 0.8397547682126371, b = 0.9592514634132386
# 2번째 hypothesis = [1.7990062 2.638761  3.4785156]
# 2번째 cost = 0.06011470407247543
# 2번째 w_grad = 0.004025061925252278
# 2번째 w = 0.8393522620201118, b = 0.9601816534996034
# 3번째 hypothesis = [1.7995338 2.6388862 3.4782386]
# 3번째 cost = 0.05994962155818939
# 3번째 w_grad = 0.0040073394775390625
# 3번째 w = 0.838951528072358, b = 0.9611076686117386
# 4번째 hypothesis = [1.8000592 2.6390107 3.4779623]
# 4번째 cost = 0.05978595092892647
# 4번째 w_grad = 0.003989100456237793
# 4번째 w = 0.8385526180267342, b = 0.9620295339160497
# 5번째 hypothesis = [1.8005822 2.6391346 3.4776874]
# 5번째 cost = 0.05962377414107323
# 5번째 w_grad = 0.003971179326375325
# 5번째 w = 0.8381555000940967, b = 0.9629472653071087
# 6번째 hypothesis = [1.8011028 2.6392584 3.4774137]
# 6번째 cost = 0.059463150799274445
# 6번째 w_grad = 0.003953496615091959
# 6번째 w = 0.8377601504325874, b = 0.9638608786794876
# 7번째 hypothesis = [1.801621  2.6393812 3.4771414]
# 7번째 cost = 0.05930387228727341
# 7번째 w_grad = 0.003935813903808594
# 7번째 w = 0.8373665690422066, b = 0.9647703952259489
# 8번째 hypothesis = [1.8021369 2.6395035 3.47687  ]
# 8번째 cost = 0.05914602056145668
# 8번째 w_grad = 0.003918011983235677
# 8번째 w = 0.836974767843883, b = 0.9656758348147075
# 9번째 hypothesis = [1.8026506 2.6396253 3.4766002]
# 9번째 cost = 0.05898957699537277
# 9번째 w_grad = 0.0039005676905314126
# 9번째 w = 0.8365847110748299, b = 0.9665772120157878
# 10번째 hypothesis = [1.8031619 2.6397467 3.4763315]
# 10번째 cost = 0.058834582567214966
# 10번째 w_grad = 0.0038832028706868487
# 10번째 w = 0.8361963907877612, b = 0.967474545372857
# 11번째 hypothesis = [1.8036709 2.6398673 3.4760635]
# 11번째 cost = 0.0586809404194355
# 11번째 w_grad = 0.0038653214772542315
# 11번째 w = 0.8358098586400358, b = 0.9683678600523208
# 12번째 hypothesis = [1.8041778 2.6399877 3.4757974]
# 12번째 cost = 0.05852867290377617
# 12번째 w_grad = 0.003848473230997721
# 12번째 w = 0.835425011316936, b = 0.9692571613523696
# 13번째 hypothesis = [1.8046823 2.6401072 3.4755323]
# 13번째 cost = 0.058377705514431
# 13번째 w_grad = 0.003831148147583008
# 13번째 w = 0.8350418965021777, b = 0.9701424757639568
# 14번째 hypothesis = [1.8051844 2.6402264 3.475268 ]
# 14번째 cost = 0.05822823941707611
# 14번째 w_grad = 0.0038135846455891924
# 14번째 w = 0.8346605380376189, b = 0.9710238244798449
# 15번째 hypothesis = [1.8056843 2.6403449 3.4750054]
# 15번째 cost = 0.05807999148964882
# 15번째 w_grad = 0.003796736399332682
# 15번째 w = 0.8342808643976856, b = 0.9719012180964153
# 16번째 hypothesis = [1.8061821 2.6404629 3.4747436]
# 16번째 cost = 0.05793306604027748
# 16번째 w_grad = 0.0037795702616373696
# 16번째 w = 0.8339029073715218, b = 0.9727746778064305
# 17번째 hypothesis = [1.8066776 2.6405804 3.4744835]
# 17번째 cost = 0.05778750032186508
# 17번째 w_grad = 0.003762960433959961
# 17번째 w = 0.8335266113281259, b = 0.9736442168553671
# 18번째 hypothesis = [1.8071709 2.6406975 3.474224 ]
# 18번째 cost = 0.05764324963092804
# 18번째 w_grad = 0.00374603271484375
# 18번째 w = 0.8331520080566415, b = 0.9745098564359878
# 19번째 hypothesis = [1.8076618 2.6408138 3.4739656]
# 19번째 cost = 0.05750031769275665
# 19번째 w_grad = 0.003728787104288737
# 19번째 w = 0.8327791293462126, b = 0.9753716203901504
# 20번째 hypothesis = [1.8081508 2.6409297 3.4737089]
# 20번째 cost = 0.05735853314399719
# 20번째 w_grad = 0.0037122567494710284
# 20번째 w = 0.8324079036712655, b = 0.9762295166651409
# 21번째 hypothesis = [1.8086374 2.6410453 3.473453 ]
# 21번째 cost = 0.05721817538142204
# 21번째 w_grad = 0.0036957263946533203
# 21번째 w = 0.8320383310318001, b = 0.9770835638046266
# 22번째 hypothesis = [1.8091218 2.6411602 3.4731984]
# 22번째 cost = 0.0570790097117424
# 22번째 w_grad = 0.003679196039835612
# 22번째 w = 0.8316704114278166, b = 0.9779337803522747
# 23번째 hypothesis = [1.8096042 2.6412745 3.4729452]
# 23번째 cost = 0.05694100260734558
# 23번째 w_grad = 0.003662904103597005
# 23번째 w = 0.8313041210174569, b = 0.9787801822026573
# 24번째 hypothesis = [1.8100843 2.6413884 3.4726927]
# 24번째 cost = 0.05680432543158531
# 24번째 w_grad = 0.003646453221638997
# 24번째 w = 0.830939475695293, b = 0.9796227878994413
# 25번째 hypothesis = [1.8105623 2.6415017 3.4724412]
# 25번째 cost = 0.05666886642575264
# 25번째 w_grad = 0.0036297241846720376
# 25번째 w = 0.8305765032768259, b = 0.9804616199599374
# 26번째 hypothesis = [1.811038  2.6416144 3.472191 ]
# 26번째 cost = 0.05653461813926697
# 26번째 w_grad = 0.0036133925120035806
# 26번째 w = 0.8302151640256255, b = 0.981296691629622
# 27번째 hypothesis = [1.8115119 2.641727  3.4719422]
# 27번째 cost = 0.05640154704451561
# 27번째 w_grad = 0.003597458203633626
# 27번째 w = 0.8298554182052621, b = 0.9821280135048763
# 28번째 hypothesis = [1.8119835 2.641839  3.4716945]
# 28번째 cost = 0.05626973137259483
# 28번째 w_grad = 0.0035816431045532227
# 28번째 w = 0.8294972538948068, b = 0.9829556028048201
# 29번째 hypothesis = [1.8124528 2.6419501 3.4714475]
# 29번째 cost = 0.05613904073834419
# 29번째 w_grad = 0.0035651524861653643
# 29번째 w = 0.8291407386461902, b = 0.9837794873449541
# 30번째 hypothesis = [1.8129202 2.642061  3.4712017]
# 30번째 cost = 0.05600951239466667
# 30번째 w_grad = 0.003549059232076009
# 30번째 w = 0.8287858327229826, b = 0.9845996777216597
# 31번째 hypothesis = [1.8133855 2.6421714 3.470957 ]
# 31번째 cost = 0.05588117241859436
# 31번째 w_grad = 0.0035331249237060547
# 31번째 w = 0.828432520230612, b = 0.9854161898295088
# 32번째 hypothesis = [1.8138487 2.642281  3.4707136]
# 32번째 cost = 0.055753882974386215
# 32번째 w_grad = 0.0035172303517659502
# 32번째 w = 0.8280807971954354, b = 0.9862290408876211
# 33번째 hypothesis = [1.8143098 2.6423907 3.4704714]
# 33번째 cost = 0.05562789365649223
# 33번째 w_grad = 0.0035018126169840493
# 33번째 w = 0.827730615933737, b = 0.9870382414923777
# 34번째 hypothesis = [1.8147688 2.6424994 3.47023  ]
# 34번째 cost = 0.055502939969301224
# 34번째 w_grad = 0.0034859975179036455
# 34번째 w = 0.8273820161819466, b = 0.9878438154856367
# 35번째 hypothesis = [1.8152258 2.642608  3.4699898]
# 35번째 cost = 0.055379126220941544
# 35번째 w_grad = 0.003470341364542643
# 35번째 w = 0.8270349820454923, b = 0.9886457761128746
# 36번째 hypothesis = [1.8156807 2.642716  3.469751 ]
# 36번째 cost = 0.055256437510252
# 36번째 w_grad = 0.003455082575480143
# 36번째 w = 0.8266894737879443, b = 0.9894441366195682
# 37번째 hypothesis = [1.8161336 2.6428232 3.4695125]
# 37번째 cost = 0.05513480678200722
# 37번째 w_grad = 0.0034391482671101885
# 37번째 w = 0.8263455589612333, b = 0.9902389221721228
# 38번째 hypothesis = [1.8165845 2.64293   3.4692757]
# 38번째 cost = 0.0550142303109169
# 38번째 w_grad = 0.0034238894780476885
# 38번째 w = 0.8260031700134285, b = 0.9910301420423723
# 39번째 hypothesis = [1.8170333 2.6430366 3.46904  ]
# 39번째 cost = 0.054894816130399704
# 39번째 w_grad = 0.0034087498982747393
# 39번째 w = 0.825662295023601, b = 0.9918178108003407
# 40번째 hypothesis = [1.8174801 2.6431425 3.4688048]
# 40번째 cost = 0.054776422679424286
# 40번째 w_grad = 0.0033931732177734375
# 40번째 w = 0.8253229777018236, b = 0.9926019509633385
# 41번째 hypothesis = [1.817925  2.6432478 3.4685707]
# 41번째 cost = 0.05465905740857124
# 41번째 w_grad = 0.0033775965372721353
# 41번째 w = 0.8249852180480964, b = 0.9933825784259375
# 42번째 hypothesis = [1.8183677 2.643353  3.468338 ]
# 42번째 cost = 0.054542846977710724
# 42번째 w_grad = 0.003362576166788737
# 42번째 w = 0.8246489604314176, b = 0.994159703784519
# 43번째 hypothesis = [1.8188087 2.6434577 3.4681067]
# 43번째 cost = 0.05442757532000542
# 43번째 w_grad = 0.0033480723698933916
# 43번째 w = 0.8243141531944282, b = 0.9949333363109167
# 44번째 hypothesis = [1.8192475 2.6435616 3.467876 ]
# 44번째 cost = 0.054313357919454575
# 44번째 w_grad = 0.003332853317260742
# 44번째 w = 0.8239808678627022, b = 0.9957035024960839
# 45번째 hypothesis = [1.8196844 2.6436653 3.4676461]
# 45번째 cost = 0.05420021340250969
# 45번째 w_grad = 0.003317793210347493
# 45번째 w = 0.8236490885416674, b = 0.996470215585497
# 46번째 hypothesis = [1.8201194 2.6437683 3.4674175]
# 46번째 cost = 0.054087985306978226
# 46번째 w_grad = 0.0033028125762939453
# 46번째 w = 0.8233188072840381, b = 0.9972334914737281
# 47번째 hypothesis = [1.8205523 2.643871  3.4671898]
# 47번째 cost = 0.05397685244679451
# 47번째 w_grad = 0.0032879511515299478
# 47번째 w = 0.822990012168885, b = 0.9979933447308014
# 48번째 hypothesis = [1.8209834 2.6439734 3.4669633]
# 48번째 cost = 0.053866688162088394
# 48번째 w_grad = 0.003273328145345052
# 48번째 w = 0.8226626793543506, b = 0.9987497886021935
# 49번째 hypothesis = [1.8214124 2.6440752 3.4667377]
# 49번째 cost = 0.05375754460692406
# 49번째 w_grad = 0.0032586654027303057
# 49번째 w = 0.8223368128140776, b = 0.9995028403070242
# 50번째 hypothesis = [1.8218396 2.6441765 3.4665134]
# 50번째 cost = 0.05364935100078583
# 50번째 w_grad = 0.003244241078694661
# 50번째 w = 0.8220123887062081, b = 1.0002525130907698
# 51번째 hypothesis = [1.8222649 2.644277  3.4662895]
# 51번째 cost = 0.053542036563158035
# 51번째 w_grad = 0.0032292207082112627
# 51번째 w = 0.821689466635387, b = 1.0009988294707408
# 52번째 hypothesis = [1.8226883 2.6443777 3.4660673]
# 52번째 cost = 0.05343577265739441
# 52번째 w_grad = 0.003215233484903971
# 52번째 w = 0.8213679432868966, b = 1.0017417920960325
# 53번째 hypothesis = [1.8231096 2.6444776 3.4658456]
# 53번째 cost = 0.05333050340414047
# 53번째 w_grad = 0.003200531005859375
# 53번째 w = 0.8210478901863106, b = 1.002481427457598
# 54번째 hypothesis = [1.8235294 2.6445773 3.4656253]
# 54번째 cost = 0.05322609469294548
# 54번째 w_grad = 0.0031865835189819336
# 54번째 w = 0.8207292318344125, b = 1.0032177395290802
# 55번째 hypothesis = [1.823947  2.6446762 3.4654055]
# 55번째 cost = 0.053122665733098984
# 55번째 w_grad = 0.0031719207763671875
# 55번째 w = 0.8204120397567758, b = 1.0039507548014326
# 56번째 hypothesis = [1.8243628 2.644775  3.4651866]
# 56번째 cost = 0.05302019044756889
# 56번째 w_grad = 0.0031574567159016924
# 56번째 w = 0.8200962940851856, b = 1.0046804851955842
# 57번째 hypothesis = [1.8247769 2.6448731 3.4649696]
# 57번째 cost = 0.05291849374771118
# 57번째 w_grad = 0.0031440258026123047
# 57번째 w = 0.8197818915049243, b = 1.00540693336063
# 58번째 hypothesis = [1.8251889 2.644971  3.4647527]
# 58번째 cost = 0.05281786248087883
# 58번째 w_grad = 0.0031295617421468096
# 58번째 w = 0.8194689353307096, b = 1.0061301284366186
# 59번째 hypothesis = [1.825599  2.645068  3.4645367]
# 59번째 cost = 0.05271807685494423
# 59번째 w_grad = 0.003114938735961914
# 59번째 w = 0.8191574414571134, b = 1.0068500889672176
# 60번째 hypothesis = [1.8260076 2.645165  3.4643226]
# 60번째 cost = 0.052619099617004395
# 60번째 w_grad = 0.0031017462412516275
# 60번째 w = 0.8188472668329883, b = 1.007566809654236
# 61번째 hypothesis = [1.8264141 2.6452613 3.4641085]
# 61번째 cost = 0.052521105855703354
# 61번째 w_grad = 0.003087361653645833
# 61번째 w = 0.8185385306676237, b = 1.008280322286818
# 62번째 hypothesis = [1.8268188 2.6453574 3.4638958]
# 62번째 cost = 0.05242399498820305
# 62번째 w_grad = 0.003073652585347493
# 62번째 w = 0.818231165409089, b = 1.0089906334877017
# 63번째 hypothesis = [1.8272219 2.645453  3.463684 ]
# 63번째 cost = 0.05232769623398781
# 63번째 w_grad = 0.003060022989908854
# 63번째 w = 0.8179251631100981, b = 1.0096977565023637
# 64번째 hypothesis = [1.8276229 2.645548  3.4634733]
# 64번째 cost = 0.05223231762647629
# 64번째 w_grad = 0.0030463536580403643
# 64번째 w = 0.8176205277442941, b = 1.0104017085499237
# 65번째 hypothesis = [1.8280222 2.6456428 3.4632633]
# 65번째 cost = 0.05213775113224983
# 65번째 w_grad = 0.0030325253804524737
# 65번째 w = 0.8173172752062489, b = 1.0111025055249536
# 66번째 hypothesis = [1.8284198 2.6457372 3.4630542]
# 66번째 cost = 0.052044082432985306
# 66번째 w_grad = 0.0030188957850138345
# 66번째 w = 0.8170153856277474, b = 1.0118001593483823
# 67번째 hypothesis = [1.8288156 2.645831  3.4628463]
# 67번째 cost = 0.05195121467113495
# 67번째 w_grad = 0.003005544344584147
# 67번째 w = 0.816714831193289, b = 1.0124946819411387
# 68번째 hypothesis = [1.8292096 2.6459243 3.4626393]
# 68번째 cost = 0.05185909941792488
# 68번째 w_grad = 0.0029920736948649087
# 68번째 w = 0.8164156238238025, b = 1.0131860905223427
# 69번째 hypothesis = [1.8296018 2.6460173 3.4624329]
# 69번째 cost = 0.05176790431141853
# 69번째 w_grad = 0.0029783248901367188
# 69번째 w = 0.8161177913347888, b = 1.0138744023111135
# 70번째 hypothesis = [1.8299922 2.64611   3.4622278]
# 70번째 cost = 0.05167754739522934
# 70번째 w_grad = 0.002965251604715983
# 70번째 w = 0.8158212661743172, b = 1.0145596239301897
# 71번째 hypothesis = [1.8303809 2.646202  3.4620237]
# 71번째 cost = 0.05158788338303566
# 71번째 w_grad = 0.002952098846435547
# 71번째 w = 0.8155260562896736, b = 1.0152417712741433
# 72번째 hypothesis = [1.8307679 2.6462939 3.4618201]
# 72번째 cost = 0.05149911716580391
# 72번째 w_grad = 0.0029386679331461587
# 72번째 w = 0.8152321894963589, b = 1.0159208615620936
# 73번째 hypothesis = [1.8311532 2.6463852 3.4616175]
# 73번째 cost = 0.05141109973192215
# 73번째 w_grad = 0.002925316492716471
# 73번째 w = 0.8149396578470872, b = 1.0165969080395174
# 74번째 hypothesis = [1.8315365 2.6464763 3.4614158]
# 74번째 cost = 0.05132397636771202
# 74번째 w_grad = 0.0029121239980061846
# 74번째 w = 0.8146484454472867, b = 1.0172699239518912
# 75번째 hypothesis = [1.8319185 2.6465669 3.4612155]
# 75번째 cost = 0.05123748257756233
# 75번째 w_grad = 0.0028995672861735025
# 75번째 w = 0.8143584887186693, b = 1.0179399145974057
# 76번째 hypothesis = [1.8322984 2.646657  3.4610152]
# 76번째 cost = 0.05115191638469696
# 76번째 w_grad = 0.0028860171635945635
# 76번째 w = 0.8140698870023099, b = 1.018606907791562
# 77번째 hypothesis = [1.8326768 2.6467466 3.4608166]
# 77번째 cost = 0.05106697604060173
# 77번째 w_grad = 0.0028733015060424805
# 77번째 w = 0.8137825568517056, b = 1.0192709075080029
# 78번째 hypothesis = [1.8330535 2.646836  3.4606185]
# 78번째 cost = 0.05098286643624306
# 78번째 w_grad = 0.0028603474299112954
# 78번째 w = 0.8134965221087145, b = 1.0199319296413003
# 79번째 hypothesis = [1.8334284 2.646925  3.4604216]
# 79번째 cost = 0.05089950188994408
# 79번째 w_grad = 0.0028476715087890625
# 79번째 w = 0.8132117549578356, b = 1.0205899861123833
# 80번째 hypothesis = [1.8338017 2.6470134 3.460225 ]
# 80번째 cost = 0.0508168488740921
# 80번째 w_grad = 0.002834637959798177
# 80번째 w = 0.8129282911618558, b = 1.0212450941403712
# 81번째 hypothesis = [1.8341734 2.6471019 3.46003  ]
# 81번째 cost = 0.05073500797152519
# 81번째 w_grad = 0.002822478612263997
# 81번째 w = 0.8126460433006294, b = 1.0218972563743596
# 82번째 hypothesis = [1.8345433 2.6471894 3.4598355]
# 82번째 cost = 0.05065380036830902
# 82번째 w_grad = 0.0028095642725626626
# 82번째 w = 0.8123650868733732, b = 1.022546497980754
# 83번째 hypothesis = [1.8349116 2.6472769 3.459642 ]
# 83번째 cost = 0.0505734384059906
# 83번째 w_grad = 0.0027970472971598306
# 83번째 w = 0.8120853821436572, b = 1.0231928269068404
# 84번째 hypothesis = [1.8352783 2.6473637 3.459449 ]
# 84번째 cost = 0.05049367621541023
# 84번째 w_grad = 0.002784252166748047
# 84번째 w = 0.8118069569269825, b = 1.0238362603717384
# 85번째 hypothesis = [1.8356433 2.6474502 3.4592571]
# 85번째 cost = 0.05041467398405075
# 85번째 w_grad = 0.0027716954549153643
# 85번째 w = 0.811529787381491, b = 1.0244768089718292
# 86번째 hypothesis = [1.8360066 2.6475363 3.4590662]
# 86번째 cost = 0.050336357206106186
# 86번째 w_grad = 0.002759218215942383
# 86번째 w = 0.8112538655598968, b = 1.0251144859525896
# 87번째 hypothesis = [1.8363683 2.647622  3.4588761]
# 87번째 cost = 0.05025878921151161
# 87번째 w_grad = 0.0027469793955485025
# 87번째 w = 0.810979167620342, b = 1.0257493019104007
# 88번째 hypothesis = [1.8367286 2.6477077 3.4586868]
# 88번째 cost = 0.050181902945041656
# 88번째 w_grad = 0.0027348200480143228
# 88번째 w = 0.8107056856155405, b = 1.026381267441644
# 89번째 hypothesis = [1.8370869 2.6477926 3.4584982]
# 89번째 cost = 0.05010571330785751
# 89번째 w_grad = 0.0027222633361816406
# 89번째 w = 0.8104334592819223, b = 1.0270104037390817
# 90번째 hypothesis = [1.8374438 2.6478772 3.4583108]
# 90번째 cost = 0.050030168145895004
# 90번째 w_grad = 0.002710262934366862
# 90번째 w = 0.8101624329884857, b = 1.0276367161009048
# 91번째 hypothesis = [1.8377992 2.6479616 3.458124 ]
# 91번째 cost = 0.049955349415540695
# 91번째 w_grad = 0.002698063850402832
# 91번째 w = 0.8098926266034454, b = 1.0282602190971375
# 92번째 hypothesis = [1.8381529 2.6480455 3.4579382]
# 92번째 cost = 0.049881163984537125
# 92번째 w_grad = 0.002686182657877604
# 92번째 w = 0.8096240083376577, b = 1.0288809233241611
# 93번째 hypothesis = [1.838505  2.648129  3.4577532]
# 93번째 cost = 0.04980761557817459
# 93번째 w_grad = 0.0026741822560628252
# 93번째 w = 0.8093565901120514, b = 1.029498843352
# 94번째 hypothesis = [1.8388554 2.648212  3.4575684]
# 94번째 cost = 0.04973480850458145
# 94번째 w_grad = 0.0026615063349405923
# 94번째 w = 0.8090904394785573, b = 1.0301140016979642
# 95번째 hypothesis = [1.8392045 2.648295  3.4573855]
# 95번째 cost = 0.04966255649924278
# 95번째 w_grad = 0.002650340398152669
# 95번째 w = 0.808825405438742, b = 1.0307263904147679
# 96번째 hypothesis = [1.8395519 2.6483774 3.4572027]
# 96번째 cost = 0.049591053277254105
# 96번째 w_grad = 0.00263826052347819
# 96번째 w = 0.8085615793863942, b = 1.0313360346688165
# 97번째 hypothesis = [1.8398976 2.6484592 3.4570208]
# 97번째 cost = 0.04952011629939079
# 97번째 w_grad = 0.0026261011759440103
# 97번째 w = 0.8082989692687997, b = 1.0319429503546822
# 98번째 hypothesis = [1.8402419 2.648541  3.4568396]
# 98번째 cost = 0.04944989085197449
# 98번째 w_grad = 0.002614180246988932
# 98번째 w = 0.8080375512441008, b = 1.0325471454196506
# 99번째 hypothesis = [1.8405848 2.6486223 3.4566598]
# 99번째 cost = 0.04938017576932907
# 99번째 w_grad = 0.002602895100911458
# 99번째 w = 0.8077772617340097, b = 1.0331486251619126
# 100번째 hypothesis = [1.8409259 2.648703  3.4564805]
# 100번째 cost = 0.049311116337776184
# 100번째 w_grad = 0.0025912125905354815
# 100번째 w = 0.8075181404749561, b = 1.0337474081251357

# %% [markdown]
# Cost 값 그려보기 및 예측된 Y값 비교

# %%
import matplotlib.pyplot as plt

plt.plot(cost_list, marker='o')
plt.plot(hypothesis_list, marker='o')
# Out:
# [<matplotlib.lines.Line2D at 0x297cc827b48>,
#  <matplotlib.lines.Line2D at 0x297cc821bc8>,
#  <matplotlib.lines.Line2D at 0x297cc829708>]
