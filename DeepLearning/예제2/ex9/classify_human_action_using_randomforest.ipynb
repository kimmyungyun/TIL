# %%
import pandas as pd

# %%
feature_name_df = pd.read_csv('./data/human_activity_features.txt', 
                              sep='\s+',
                              header=None,
                              names=['column_index', 'column_name']
                             )
feature_name_df
# Out:
#      column_index                           column_name
# 0               1                     tBodyAcc-mean()-X
# 1               2                     tBodyAcc-mean()-Y
# 2               3                     tBodyAcc-mean()-Z
# 3               4                      tBodyAcc-std()-X
# 4               5                      tBodyAcc-std()-Y
# ..            ...                                   ...
# 556           557      angle(tBodyGyroMean,gravityMean)
# 557           558  angle(tBodyGyroJerkMean,gravityMean)
# 558           559                  angle(X,gravityMean)
# 559           560                  angle(Y,gravityMean)
# 560           561                  angle(Z,gravityMean)
#
# [561 rows x 2 columns]

# %%
feature_name = feature_name_df.iloc[:, 1].values.tolist()
feature_name
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
X_train = pd.read_csv('./data/human_activity_X_train.txt',
           sep='\s+',
           header=None)
X_train
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078 -0.282301
# 7348  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280 -0.322552
# 7349  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533 -0.304515
# 7350  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893 -0.310487
# 7351  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404 -0.377404
#
# ...

# %%
X_train.columns = feature_name
X_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
y_train = pd.read_csv('./data/human_activity_y_train.txt',
                     sep='\s+',
                     header=None,
                     names=['action'])
y_train
# Out:
#       action
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 7347       2
# 7348       2
# 7349       2
# 7350       2
# 7351       2
#
# [7352 rows x 1 columns]

# %% [markdown]
# ## 결측치가 존재하지 않음

# %%
X_train.isnull().sum().sum()
# Out:
# 0

# %%
import numpy as np

# %%
np.sqrt(561)
# Out:
# 23.68543856465402

# %%
num = int(np.sqrt(561))

# %% [markdown]
# ## 최적의 Random Forest 찾기

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'n_estimators' : [100],
    'max_depth' : [4, 8, 16, 32],
    'min_samples_leaf' : [8, 16, 32, 64],
    'min_samples_split' : [num, num*2, num*3, num*4]
}

# %%
rf_clf = RandomForestClassifier(n_jobs=16)
rf_clf
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=16, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
grid_cv = GridSearchCV(rf_clf, param_grid = params, n_jobs=16)
grid_cv
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=16,
#                                               oob_score=False,
# ...

# %% [markdown]
# ## 최고의 성능을 나타냈던 파라미터를 찾는 과정

# %%
grid_cv.fit(X_train, y_train)
# Out:
# c:\library\python\lib\site-packages\sklearn\model_selection\_search.py:739: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
# ...

# %%
print(f"최적 하이퍼 파라미터 : {grid_cv.best_params_}")
print("최고 예측 정확도 : {0:.4f}".format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터 : {'max_depth': 32, 'min_samples_leaf': 16, 'min_samples_split': 23, 'n_estimators': 100}
# 최고 예측 정확도 : 0.9232

# %% [markdown]
# ## 최고의 성능을 갖는 파라미터를 기반으로 파라미터 형성

# %%
rf_clf1 = RandomForestClassifier(n_estimators=100,
                                max_depth=32,
                                min_samples_leaf=16,
                                min_samples_split=8)
rf_clf1
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=32, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=16, min_samples_split=8,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ## 훈련

# %%
rf_clf1.fit(X_train, y_train)
# Out:
# c:\library\python\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=32, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=16, min_samples_split=8,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
X_test = pd.read_csv('./data/human_activity_X_test.txt',
           sep='\s+',
           header=None)
X_test
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1     0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2     0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3     0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4     0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
# ...        ...       ...       ...       ...       ...       ...       ...
# 2942  0.310155 -0.053391 -0.099109 -0.287866 -0.140589 -0.215088 -0.356083
# 2943  0.363385 -0.039214 -0.105915 -0.305388  0.028148 -0.196373 -0.373540
# 2944  0.349966  0.030077 -0.115788 -0.329638 -0.042143 -0.250181 -0.388017
# 2945  0.237594  0.018467 -0.096499 -0.323114 -0.229775 -0.207574 -0.392380
# 2946  0.153627 -0.018437 -0.137018 -0.330046 -0.195253 -0.164339 -0.430974
#
# ...

# %%
y_test = pd.read_csv('./data/human_activity_y_test.txt',
                     sep='\s+',
                     header=None,
                     names=['action'])
y_test
# Out:
#       action
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 2942       2
# 2943       2
# 2944       2
# 2945       2
# 2946       2
#
# [2947 rows x 1 columns]

# %%
X_test.columns = feature_name
X_test
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
pred = rf_clf1.predict(X_test)
pred
# Out:
# array([5, 5, 5, ..., 2, 2, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print(f"예측 정확도 : {accuracy_score(y_test, pred)}")
# Out:
# 예측 정확도 : 0.9110960298608755
