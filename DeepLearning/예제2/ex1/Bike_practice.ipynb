# %% [markdown]
# # Kaggle 자전거 데이터
# - https://www.kaggle.com/c/bike-sharing-demand
# - 데이터 분석 및 성능 향상을 위한 전처리

# %% [markdown]
# ## 기본 방식

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib inline
plt.style.use('ggplot')

# %%
train = pd.read_csv("data/bike.csv")
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %% [markdown]
# ## datetime 데이터를 string에서 datetime 으로 타입 변경

# %%
train["datetime"] = pd.to_datetime(train["datetime"])

# %% [markdown]
# ## 결측치 확인

# %%
train.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# ## 날짜 데이터를 활용한 열 추가

# %%
datetime = train["datetime"]

# %%
train["year"] = datetime.dt.year
train["year"].head()
# Out:
# 0    2011
# 1    2011
# 2    2011
# 3    2011
# 4    2011
# Name: year, dtype: int64

# %%
train["month"] = datetime.dt.month
train["month"].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: month, dtype: int64

# %%
train["day"] = datetime.dt.day
train["day"].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: day, dtype: int64

# %%
train["hour"] = datetime.dt.hour
train["hour"].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: hour, dtype: int64

# %%
train["minute"] = datetime.dt.minute
train["minute"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: minute, dtype: int64

# %%
train["second"] = datetime.dt.second
train["second"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: second, dtype: int64

# %%
train["dayofweek"] = datetime.dt.dayofweek
train["dayofweek"].head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: dayofweek, dtype: int64

# %%
def set_workingday(x):
    if x<5:
        return 1
    else:
        return 0

# %%
train["workingday"] = train.apply(lambda x: set_workingday(x['dayofweek']), axis = 1)
train["workingday"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: workingday, dtype: int64

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second  dayofweek
# 0       0       0          5
# 1       0       0          5
# 2       0       0          5
# 3       0       0          5
# 4       0       0          5

# %% [markdown]
# ## year 컬럼을 기준으로 count 값 비교

# %%
sns.barplot(data = train, x="year", y="count")

# %%
sns.barplot(data = train, x="month", y="count")

# %%
sns.barplot(data = train, x="day", y="count")

# %%
sns.barplot(data = train, x="hour", y="count")

# %%
sns.barplot(data = train, x="minute", y="count")

# %%
sns.barplot(data = train, x="second", y="count")

# %%
sns.pointplot(data = train, x="hour", y="count", hue="workingday")

# %%
sns.pointplot(data = train, x="hour", y="count", hue="dayofweek")

# %% [markdown]
# - 1=맑음,약간 구름낀 흐림
# - 2=안개, 안개+흐림
# - 3=가벼운눈, 가벼운비+천둥
# - 4=심한눈/비, 천둥/번개

# %%
sns.pointplot(data=train, x="hour", y="count", hue="weather")

# %% [markdown]
# - 1=봄, 2=여름, 3=가을, 4=겨울

# %%
sns.pointplot(data=train, x="hour", y="count", hue="season")

# %%
sns.regplot(x="windspeed", y="count", data=train)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
sns.heatmap(train.corr(), annot=True, cmap="RdBu_r")

# %% [markdown]
# ## count 값의 이상치 제거

# %%
Q1 = train['count'].quantile(0.25)
Q3 = train['count'].quantile(0.75)
IQR = Q3-Q1
train_outlier = train[ (train['count'] >= Q1 - 1.5*IQR) & train['count'] <= Q3 + 1.5 * IQR]

# %%
train_outlier.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second  dayofweek
# 0       0       0          5
# 1       0       0          5
# 2       0       0          5
# 3       0       0          5
# 4       0       0          5

# %% [markdown]
# ## 데이터 정규화

# %%
sns.distplot(train_outlier["count"])

# %%
train_outlier["count"] = np.log1p(train["count"])
sns.distplot(train_outlier["count"])

# %% [markdown]
# ## 선형회귀

# %%
y = train_outlier["count"]
y.head()
# Out:
# 0    2.833213
# 1    3.713572
# 2    3.496508
# 3    2.639057
# 4    0.693147
# Name: count, dtype: float64

# %%
X = train_outlier
X.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered     count  year  month  day  hour  \
# 0        81        0.0       3          13  2.833213  2011      1    1     0
# 1        80        0.0       8          32  3.713572  2011      1    1     1
# 2        80        0.0       5          27  3.496508  2011      1    1     2
# 3        75        0.0       3          10  2.639057  2011      1    1     3
# 4        75        0.0       0           1  0.693147  2011      1    1     4
#
#    minute  second  dayofweek
# 0       0       0          5
# 1       0       0          5
# 2       0       0          5
# 3       0       0          5
# 4       0       0          5

# %%
X.pop("count")
X.pop("datetime")
X.pop("registered")
X.pop("day")
X.pop("minute")
X.pop("second")
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10881    0
# 10882    0
# 10883    0
# 10884    0
# 10885    0
# Name: second, Length: 10886, dtype: int64

# %% [markdown]
# ## 데이터 나누기

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = model.predict(X_train)

# %%
model.score(X_train, y_train)
# Out:
# 0.5682020486644732

# %%
from sklearn.metrics import mean_squared_error
print("MSE : ", mean_squared_error(pred, y_train))
# Out:
# MSE :  0.8716793031508859

# %%
X_test
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 4717        4        0           1        1  21.32  25.000        45
# 3649        3        0           1        2  26.24  30.305        73
# 10134       4        0           1        2  13.12  15.150        53
# 4243        4        0           0        1  21.32  25.000        77
# 3817        3        0           0        2  25.42  27.275        94
# ...       ...      ...         ...      ...    ...     ...       ...
# 9720        4        0           1        2  17.22  21.210        77
# 9919        4        0           1        1  22.96  26.515        52
# 1490        2        0           1        1  15.58  19.695        76
# 9412        3        0           0        1  27.88  31.820        36
# 102         1        0           1        1  10.66  11.365        33
#
#        windspeed  casual  year  month  hour  dayofweek
# 4717     15.0013      21  2011     11    15          2
# 3649     11.0014      30  2011      9    23          4
# 10134    19.9995      20  2012     11    15          2
# 4243      7.0015      78  2011     10    20          5
# 3817      0.0000      16  2011      9     1          5
# ...          ...     ...   ...    ...   ...        ...
# 9720     15.0013      37  2012     10     9          1
# 9919     12.9980      70  2012     10    16          2
# 1490     16.9979       9  2011      4    23          3
# 9412     12.9980     327  2012      9    13          5
# 102      22.0028      12  2011      1    11          2
#
# [2178 rows x 13 columns]

# %%
pred = model.predict(X_test)

print("MSE : ", mean_squared_error(pred, y_test))
# Out:
# MSE :  0.8911052802836906

# %%
model.score(X_test, y_test)
# Out:
# 0.5541018539402346

# %% [markdown]
# # 성능 올리기

# %%
train_outlier.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B40F2C9248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410BC9A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410C00248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410C37908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B410C6F788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410CA6888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410CDE988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410D16AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B410D21688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410D58848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410DBDE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410DF5E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B410E2CF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410E68108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410EA02C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B410ED7488>]],
#       dtype=object)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
sns.heatmap(train_outlier.corr(), annot=True, cmap="RdBu_r")

# %%
sns.pointplot(data = train, x="hour", y="count", hue="holiday")

# %%
train_outlier['temp'].describe()
# Out:
# count    10886.00000
# mean        20.23086
# std          7.79159
# min          0.82000
# 25%         13.94000
# 50%         20.50000
# 75%         26.24000
# max         41.00000
# Name: temp, dtype: float64

# %% [markdown]
# # 기온을 표준화 하기

# %%
#나쁘지 않은듯..?
train_outlier["temp"] = (train["temp"]-train["temp"].mean())/train["temp"].std()
# Out:
# c:\library\python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # windspeed에서 0의 값을 온도, 습도, weather를 통해서 예측하자

# %%
wind_data = train_outlier[ train_outlier["windspeed"] != 0]
Q1 = wind_data["windspeed"].quantile(0.25)
Q3 = wind_data["windspeed"].quantile(0.75)
IQR = Q3-Q1
wind_data = wind_data[ (wind_data["windspeed"] >= Q1 - 1.5*IQR) & (wind_data["windspeed"] <= Q3 + 1.5 * IQR)]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
sns.heatmap(wind_data.loc[:,["temp", "humidity", "weather", "windspeed"]].corr(), annot=True, cmap="RdBu_r")

# %%
wind_data["windspeed"] = np.log1p(wind_data["windspeed"])
sns.distplot(wind_data["windspeed"])

# %%
wind_x = wind_data.loc[:,["temp", "humidity", "weather"]]
wind_y = wind_data["windspeed"]

# %% [markdown]
# # 상관계수도 낮고, 정확도도 떨어져서 사용이 안될 듯

# %%
wind_x_train, wind_x_test, wind_y_train, wind_y_test = train_test_split(wind_x, wind_y, test_size=0.2)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(wind_x_train, wind_y_train)

pred = model.predict(wind_x_train)

from sklearn.metrics import mean_squared_error
print("MSE : ", mean_squared_error(pred, wind_y_train))

print("Score : ", model.score(wind_x_train, wind_y_train))

pred = model.predict(wind_x_test)

print("MSE : ", mean_squared_error(pred, wind_y_test))

print("Score : ", model.score(wind_x_test, wind_y_test))
# Out:
# MSE :  0.15993953546343317
# Score :  0.1254772047285294
# MSE :  0.15955448404343
# Score :  0.10578612558861113

# %% [markdown]
# ## 테스트 하기전 데이터 초기화 부분

# %%
Q1 = train['count'].quantile(0.25)
Q3 = train['count'].quantile(0.75)
IQR = Q3-Q1
train_outlier = train[ (train['count'] >= Q1 - 1.5*IQR) & (train['count'] <= Q3 + 1.5 * IQR)]

# %% [markdown]
# # 테스트 하기 위한 코드 부분

# %%
from sklearn.model_selection import train_test_split


X = train_outlier
y = train_outlier["count"]

X.pop("casual")
X.pop("count")
X.pop("datetime")
X.pop("registered")
X.pop("day")
X.pop("minute")
X.pop("second")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_train)

from sklearn.metrics import mean_squared_error
print("MSE : ", mean_squared_error(pred, y_train))

print("Score : ", model.score(X_train, y_train))

pred = model.predict(X_test)

print("MSE : ", mean_squared_error(pred, y_test))

print("Score : ", model.score(X_test, y_test))
# Out:
# MSE :  14935.427124629126
# Score :  0.39279645851734757
# MSE :  14302.452965961447
# Score :  0.4000762148513182

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_train)

from sklearn.metrics import mean_squared_error
print("MSE : ", mean_squared_error(pred, y_train))

print("Score : ", model.score(X_train, y_train))

pred = model.predict(X_test)

print("MSE : ", mean_squared_error(pred, y_test))

print("Score : ", model.score(X_test, y_test))
# Out:
# MSE :  12781.280215821365
# Score :  0.6076029428602266
# MSE :  13148.422205960613
# Score :  0.6103258884960493

# %%
train_outlier
# Out:
#        season  holiday  workingday  weather      temp   atemp  humidity  \
# 0           1        0           0        1 -1.333599  14.395        81
# 1           1        0           0        1 -1.438841  13.635        80
# 2           1        0           0        1 -1.438841  13.635        80
# 3           1        0           0        1 -1.333599  14.395        75
# 4           1        0           0        1 -1.333599  14.395        75
# ...       ...      ...         ...      ...       ...     ...       ...
# 10881       4        0           1        1 -0.596908  19.695        50
# 10882       4        0           1        1 -0.702149  17.425        57
# 10883       4        0           1        1 -0.807391  15.910        61
# 10884       4        0           1        1 -0.807391  17.425        61
# 10885       4        0           1        1 -0.912633  16.665        66
#
#        windspeed  year  month  hour  dayofweek
# 0         0.0000  2011      1     0          5
# 1         0.0000  2011      1     1          5
# 2         0.0000  2011      1     2          5
# 3         0.0000  2011      1     3          5
# 4         0.0000  2011      1     4          5
# ...          ...   ...    ...   ...        ...
# 10881    26.0027  2012     12    19          2
# 10882    15.0013  2012     12    20          2
# 10883    15.0013  2012     12    21          2
# 10884     6.0032  2012     12    22          2
# 10885     8.9981  2012     12    23          2
#
# [10886 rows x 12 columns]
